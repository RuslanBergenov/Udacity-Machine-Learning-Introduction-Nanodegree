# %% [markdown]
# ### PCA Mini Project
#
# In the lesson, you saw how you could use PCA to substantially reduce the dimensionality of the handwritten digits.  In this mini-project, you will be using the **cars.csv** file.
#
# To begin, run the cell below to read in the necessary libraries and the dataset.  I also read in the helper functions that you used throughout the lesson in case you might find them helpful in completing this project.  Otherwise, you can always create functions of your own!

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
from helper_functions import do_pca, scree_plot, plot_components, pca_results
from IPython import display
import test_code2 as t

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

df = pd.read_csv('./data/cars.csv')

# %% [markdown]
# `1.` Now your data is stored in **df**.  Use the below cells to take a look your dataset.  At the end of your exploration, use your findings to match the appropriate variable to each key in the dictionary below.

# %%
df.head(50)
# Out:
#                                      Sports  SUV  Wagon  Minivan  Pickup  AWD  \
# Acura 3.5 RL                              0    0      0        0       0    0
# Acura 3.5 RL Navigation                   0    0      0        0       0    0
# Acura MDX                                 0    1      0        0       0    1
# Acura NSX S                               1    0      0        0       0    0
# Acura RSX                                 0    0      0        0       0    0
# Acura TL                                  0    0      0        0       0    0
# Acura TSX                                 0    0      0        0       0    0
# Audi A4 1.8T                              0    0      0        0       0    0
# Audi A4 1.8T convertible                  0    0      0        0       0    0
# Audi A4 3.0 convertible                   0    0      0        0       0    0
# Audi A4 3.0                               0    0      0        0       0    0
# Audi A4 3.0 Quattro manual                0    0      0        0       0    1
# Audi A4 3.0 Quattro auto                  0    0      0        0       0    1
# Audi A4 3.0 Quattro convertible           0    0      0        0       0    1
# Audi A6 2.7 Turbo Quattro four-door       0    0      0        0       0    1
# Audi A6 3.0                               0    0      0        0       0    0
# Audi A6 3.0 Avant Quattro                 0    0      1        0       0    1
# Audi A6 3.0 Quattro                       0    0      0        0       0    1
# Audi A6 4.2 Quattro                       0    0      0        0       0    1
# Audi A8 L Quattro                         0    0      0        0       0    1
# Audi S4 Avant Quattro                     0    0      1        0       0    1
# Audi S4 Quattro                           0    0      0        0       0    1
# Audi RS 6                                 1    0      0        0       0    0
# Audi TT 1.8                               1    0      0        0       0    0
# Audi TT 1.8 Quattro                       1    0      0        0       0    1
# Audi TT 3.2                               1    0      0        0       0    1
# BMW 325i                                  0    0      0        0       0    0
# BMW 325Ci                                 0    0      0        0       0    0
# BMW 325Ci convertible                     0    0      0        0       0    0
# BMW 325xi                                 0    0      0        0       0    1
# BMW 325xi Sport                           0    0      1        0       0    1
# BMW 330Ci                                 0    0      0        0       0    0
# BMW 330Ci convertible                     0    0      0        0       0    0
# BMW 330i                                  0    0      0        0       0    0
# BMW 330xi                                 0    0      0        0       0    1
# BMW 525i four-door                        0    0      0        0       0    0
# BMW 530i four-door                        0    0      0        0       0    0
# BMW 545iA four-door                       0    0      0        0       0    0
# BMW 745i four-door                        0    0      0        0       0    0
# BMW 745Li four-door                       0    0      0        0       0    0
# BMW M3                                    1    0      0        0       0    0
# BMW M3 convertible                        1    0      0        0       0    0
# BMW X3 3.0i                               0    1      0        0       0    1
# BMW X5 4.4i                               0    1      0        0       0    1
# BMW Z4 convertible 2.5i two-door          1    0      0        0       0    0
# BMW Z4 convertible 3.0i two-door          1    0      0        0       0    0
# Buick Century Custom                      0    0      0        0       0    0
# Buick LeSabre Custom four-door            0    0      0        0       0    0
# Buick LeSabre Limited                     0    0      0        0       0    0
# Buick Park Avenue                         0    0      0        0       0    0
#
#                                      RWD  Retail  Dealer  Engine  Cylinders  \
# Acura 3.5 RL                           0   43755   39014     3.5          6
# Acura 3.5 RL Navigation                0   46100   41100     3.5          6
# Acura MDX                              0   36945   33337     3.5          6
# Acura NSX S                            1   89765   79978     3.2          6
# Acura RSX                              0   23820   21761     2.0          4
# Acura TL                               0   33195   30299     3.2          6
# Acura TSX                              0   26990   24647     2.4          4
# Audi A4 1.8T                           0   25940   23508     1.8          4
# Audi A4 1.8T convertible               0   35940   32506     1.8          4
# Audi A4 3.0 convertible                0   42490   38325     3.0          6
# Audi A4 3.0                            0   31840   28846     3.0          6
# Audi A4 3.0 Quattro manual             0   33430   30366     3.0          6
# Audi A4 3.0 Quattro auto               0   34480   31388     3.0          6
# Audi A4 3.0 Quattro convertible        0   44240   40075     3.0          6
# Audi A6 2.7 Turbo Quattro four-door    0   42840   38840     2.7          6
# Audi A6 3.0                            0   36640   33129     3.0          6
# Audi A6 3.0 Avant Quattro              0   40840   37060     3.0          6
# Audi A6 3.0 Quattro                    0   39640   35992     3.0          6
# Audi A6 4.2 Quattro                    0   49690   44936     4.2          8
# Audi A8 L Quattro                      0   69190   64740     4.2          8
# Audi S4 Avant Quattro                  0   49090   44446     4.2          8
# Audi S4 Quattro                        0   48040   43556     4.2          8
# Audi RS 6                              0   84600   76417     4.2          8
# Audi TT 1.8                            0   35940   32512     1.8          4
# Audi TT 1.8 Quattro                    0   37390   33891     1.8          4
# Audi TT 3.2                            0   40590   36739     3.2          6
# BMW 325i                               1   28495   26155     2.5          6
# BMW 325Ci                              1   30795   28245     2.5          6
# BMW 325Ci convertible                  1   37995   34800     2.5          6
# BMW 325xi                              0   30245   27745     2.5          6
# BMW 325xi Sport                        0   32845   30110     2.5          6
# BMW 330Ci                              1   36995   33890     3.0          6
# BMW 330Ci convertible                  1   44295   40530     3.0          6
# BMW 330i                               1   35495   32525     3.0          6
# BMW 330xi                              0   37245   34115     3.0          6
# BMW 525i four-door                     1   39995   36620     2.5          6
# BMW 530i four-door                     1   44995   41170     3.0          6
# BMW 545iA four-door                    1   54995   50270     4.4          8
# BMW 745i four-door                     1   69195   63190     4.4          8
# BMW 745Li four-door                    1   73195   66830     4.4          8
# BMW M3                                 1   48195   44170     3.2          6
# BMW M3 convertible                     1   56595   51815     3.2          6
# BMW X3 3.0i                            0   37000   33873     3.0          6
# BMW X5 4.4i                            0   52195   47720     4.4          8
# BMW Z4 convertible 2.5i two-door       1   33895   31065     2.5          6
# BMW Z4 convertible 3.0i two-door       1   41045   37575     3.0          6
# Buick Century Custom                   0   22180   20351     3.1          6
# Buick LeSabre Custom four-door         0   26470   24282     3.8          6
# Buick LeSabre Limited                  0   32245   29566     3.8          6
# Buick Park Avenue                      0   35545   32244     3.8          6
#
#                                      Horsepower  CityMPG  HighwayMPG  Weight  \
# Acura 3.5 RL                                225       18          24    3880
# Acura 3.5 RL Navigation                     225       18          24    3893
# Acura MDX                                   265       17          23    4451
# Acura NSX S                                 290       17          24    3153
# Acura RSX                                   200       24          31    2778
# Acura TL                                    270       20          28    3575
# Acura TSX                                   200       22          29    3230
# Audi A4 1.8T                                170       22          31    3252
# Audi A4 1.8T convertible                    170       23          30    3638
# Audi A4 3.0 convertible                     220       20          27    3814
# Audi A4 3.0                                 220       20          28    3462
# Audi A4 3.0 Quattro manual                  220       17          26    3583
# Audi A4 3.0 Quattro auto                    220       18          25    3627
# Audi A4 3.0 Quattro convertible             220       18          25    4013
# Audi A6 2.7 Turbo Quattro four-door         250       18          25    3836
# Audi A6 3.0                                 220       20          27    3561
# Audi A6 3.0 Avant Quattro                   220       18          25    4035
# Audi A6 3.0 Quattro                         220       18          25    3880
# Audi A6 4.2 Quattro                         300       17          24    4024
# Audi A8 L Quattro                           330       17          24    4399
# Audi S4 Avant Quattro                       340       15          21    3936
# Audi S4 Quattro                             340       14          20    3825
# Audi RS 6                                   450       15          22    4024
# Audi TT 1.8                                 180       20          28    3131
# Audi TT 1.8 Quattro                         225       20          28    2921
# Audi TT 3.2                                 250       21          29    3351
# BMW 325i                                    184       20          29    3219
# BMW 325Ci                                   184       20          29    3197
# BMW 325Ci convertible                       184       19          27    3560
# BMW 325xi                                   184       19          27    3461
# BMW 325xi Sport                             184       19          26    3594
# BMW 330Ci                                   225       20          30    3285
# BMW 330Ci convertible                       225       19          28    3616
# BMW 330i                                    225       20          30    3285
# BMW 330xi                                   225       20          29    3483
# BMW 525i four-door                          184       19          28    3428
# BMW 530i four-door                          225       20          30    3472
# BMW 545iA four-door                         325       18          26    3814
# BMW 745i four-door                          325       18          26    4376
# BMW 745Li four-door                         325       18          26    4464
# BMW M3                                      333       16          24    3415
# BMW M3 convertible                          333       16          23    3781
# BMW X3 3.0i                                 225       16          23    4023
# BMW X5 4.4i                                 325       16          22    4824
# BMW Z4 convertible 2.5i two-door            184       20          28    2932
# BMW Z4 convertible 3.0i two-door            225       21          29    2998
# Buick Century Custom                        175       20          30    3353
# Buick LeSabre Custom four-door              205       20          29    3567
# Buick LeSabre Limited                       205       20          29    3591
# Buick Park Avenue                           205       20          29    3778
#
#                                      Wheelbase  Length  Width
# Acura 3.5 RL                               115     197     72
# Acura 3.5 RL Navigation                    115     197     72
# Acura MDX                                  106     189     77
# Acura NSX S                                100     174     71
# Acura RSX                                  101     172     68
# Acura TL                                   108     186     72
# Acura TSX                                  105     183     69
# Audi A4 1.8T                               104     179     70
# Audi A4 1.8T convertible                   105     180     70
# Audi A4 3.0 convertible                    105     180     70
# Audi A4 3.0                                104     179     70
# Audi A4 3.0 Quattro manual                 104     179     70
# Audi A4 3.0 Quattro auto                   104     179     70
# Audi A4 3.0 Quattro convertible            105     180     70
# Audi A6 2.7 Turbo Quattro four-door        109     192     71
# Audi A6 3.0                                109     192     71
# Audi A6 3.0 Avant Quattro                  109     192     71
# Audi A6 3.0 Quattro                        109     192     71
# Audi A6 4.2 Quattro                        109     193     71
# Audi A8 L Quattro                          121     204     75
# Audi S4 Avant Quattro                      104     179     70
# Audi S4 Quattro                            104     179     70
# Audi RS 6                                  109     191     78
# Audi TT 1.8                                 95     159     73
# Audi TT 1.8 Quattro                         96     159     73
# Audi TT 3.2                                 96     159     73
# BMW 325i                                   107     176     69
# BMW 325Ci                                  107     177     69
# BMW 325Ci convertible                      107     177     69
# BMW 325xi                                  107     176     69
# BMW 325xi Sport                            107     176     69
# BMW 330Ci                                  107     176     69
# BMW 330Ci convertible                      107     177     69
# BMW 330i                                   107     176     69
# BMW 330xi                                  107     176     69
# BMW 525i four-door                         114     191     73
# BMW 530i four-door                         114     191     73
# BMW 545iA four-door                        114     191     73
# BMW 745i four-door                         118     198     75
# BMW 745Li four-door                        123     204     75
# BMW M3                                     108     177     70
# BMW M3 convertible                         108     177     70
# BMW X3 3.0i                                110     180     73
# BMW X5 4.4i                                111     184     74
# BMW Z4 convertible 2.5i two-door            98     161     70
# BMW Z4 convertible 3.0i two-door            98     161     70
# Buick Century Custom                       109     195     73
# Buick LeSabre Custom four-door             112     200     74
# Buick LeSabre Limited                      112     200     74
# Buick Park Avenue                          114     207     75

# %%
#Use this cell for work
print(df.shape)
print()
print(df.columns)
print()
print(df.info())
# check date types
print()
df.dtypes
print()
print(df.describe())
# Out:
# (387, 18)
#
# Index(['Sports', 'SUV', 'Wagon', 'Minivan', 'Pickup', 'AWD', 'RWD', 'Retail',
#        'Dealer', 'Engine', 'Cylinders', 'Horsepower', 'CityMPG', 'HighwayMPG',
#        'Weight', 'Wheelbase', 'Length', 'Width'],
#       dtype='object')
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 387 entries, Acura 3.5 RL to Volvo XC90 T6
# Data columns (total 18 columns):
# Sports        387 non-null int64
# SUV           387 non-null int64
# Wagon         387 non-null int64
# Minivan       387 non-null int64
# Pickup        387 non-null int64
# AWD           387 non-null int64
# RWD           387 non-null int64
# Retail        387 non-null int64
# Dealer        387 non-null int64
# Engine        387 non-null float64
# Cylinders     387 non-null int64
# Horsepower    387 non-null int64
# CityMPG       387 non-null int64
# HighwayMPG    387 non-null int64
# Weight        387 non-null int64
# Wheelbase     387 non-null int64
# Length        387 non-null int64
# Width         387 non-null int64
# dtypes: float64(1), int64(17)
# memory usage: 57.4+ KB
# None
#
#
#            Sports         SUV       Wagon     Minivan  Pickup         AWD  \
# count  387.000000  387.000000  387.000000  387.000000   387.0  387.000000
# mean     0.116279    0.152455    0.072351    0.054264     0.0    0.201550
# std      0.320974    0.359926    0.259404    0.226830     0.0    0.401677
# min      0.000000    0.000000    0.000000    0.000000     0.0    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000     0.0    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000     0.0    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000     0.0    0.000000
# max      1.000000    1.000000    1.000000    1.000000     0.0    1.000000
#
#               RWD         Retail         Dealer      Engine   Cylinders  \
# count  387.000000     387.000000     387.000000  387.000000  387.000000
# mean     0.242894   33231.180879   30440.653747    3.127390    5.757106
# std      0.429387   19724.634576   17901.179282    1.014314    1.490182
# min      0.000000   10280.000000    9875.000000    1.400000    3.000000
# 25%      0.000000   20997.000000   19575.000000    2.300000    4.000000
# 50%      0.000000   28495.000000   26155.000000    3.000000    6.000000
# 75%      0.000000   39552.500000   36124.000000    3.800000    6.000000
# max      1.000000  192465.000000  173560.000000    6.000000   12.000000
#
#        Horsepower     CityMPG  HighwayMPG       Weight   Wheelbase  \
# count  387.000000  387.000000  387.000000   387.000000  387.000000
# mean   214.444444   20.312661   27.263566  3532.457364  107.211886
# std     70.262822    5.262333    5.636005   706.003622    7.086553
# min     73.000000   10.000000   12.000000  1850.000000   89.000000
# 25%    165.000000   18.000000   24.000000  3107.000000  103.000000
# 50%    210.000000   19.000000   27.000000  3469.000000  107.000000
# 75%    250.000000   21.500000   30.000000  3922.000000  112.000000
# max    493.000000   60.000000   66.000000  6400.000000  130.000000
#
#            Length       Width
# count  387.000000  387.000000
# mean   184.961240   71.276486
# std     13.237999    3.368329
# min    143.000000   64.000000
# 25%    177.000000   69.000000
# 50%    186.000000   71.000000
# 75%    193.000000   73.000000
# max    221.000000   81.000000

# %%
# and this one

# %%
# and this one if you need it - and create more cells if you need them

# %%
a = 7
b = 66
c = 387
d = 18
e = 0.23
f = 0.05

solution_1_dict = {
    'The number of cars in the dataset': c,
    'The number of car features in the dataset': d,
    'The number of dummy variables in the dataset': a,
    'The proportion of minivans in the dataset': f,
    'The max highway mpg for any car': b
}

# %%
# Check your solution against ours by running this cell
display.HTML(t.check_question_one(solution_1_dict))
# Out:
# Nice job!  Looks like your dataset matches what we found!
# <img src="https://bit.ly/2K9X0gD">

# %% [markdown]
# `2.` There are some particularly nice properties about PCA to keep in mind.  Use the dictionary below to match the correct variable as the key to each statement.  When you are ready, check your solution against ours by running the following cell.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = True
b = False

solution_2_dict = {
    'The components span the directions of maximum variability.': a,
    'The components are always orthogonal to one another.': a,
    'Eigenvalues tell us the amount of information a component holds': a
}

# %%
# Check your solution against ours by running this cell
t.check_question_two(solution_2_dict)
# Out:
# That's right these are all true.  Principal components are orthogonal, span the directions of maximum variability, and the corresponding eigenvalues tell us how much of the original variability is explained by each component.

# %% [markdown]
# `3.` Fit PCA to reduce the current dimensionality of the datset to 3 dimensions.  You can use the helper functions, or perform the steps on your own.  If you fit on your own, be sure to standardize your data.  At the end of this process, you will want an X matrix with the reduced dimensionality to only 3 features.  Additionally, you will want your **pca** object back that has been used to fit and transform your dataset.

# %%
#Scale your data, fit, and transform using pca
#you need a pca object and your transformed data matrix
pca, X_pca = do_pca(3, df)
# Out:
# C:\Users\ruslan.bergenov\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\ruslan.bergenov\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
df.shape
# Out:
# (387, 18)

# %%
X_pca.shape
# Out:
# (387, 3)

# %%
X_pca
# Out:
# array([[-1.3407057 , -0.50545972, -0.73915302],
#        [-1.4077333 , -0.42751187, -0.73420758],
#        [-2.2799534 , -1.51801955,  2.49086769],
#        ...,
#        [ 2.58874602,  0.11050253,  0.29019599],
#        [ 0.00518409, -0.81969819,  1.19121204],
#        [-2.67612795, -1.58019347,  2.53650317]])

# %%
pca
# Out:
# PCA(copy=True, iterated_power='auto', n_components=3, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %% [markdown]
# `4.` Once you have your pca object, you can take a closer look at what comprises each of the principal components.  Use the **pca_results** function from the **helper_functions** module assist with taking a closer look at the results of your analysis.  The function takes two arguments: the full dataset and the pca object you created.

# %%
pca_results?

# %% [markdown]
# `5.` Use the results, to match each of the variables as the value to the most appropriate key in the dictionary below.  When you are ready to check your answers, run the following cell to see if your solution matches ours!

# %%
my_pca_results = pca_results(df, pca)

# %%
my_pca_results['Explained Variance'].sum()
# Out:
# 0.7053

# %%
0.4352 + 0.1667 + 0.1034
# Out:
# 0.7053

# %%
a = 'car weight'
b = 'sports cars'
c = 'gas mileage'
d = 0.4352
e = 0.3061
f = 0.1667
g = 0.7053

solution_5_dict = {
    'The first component positively weights items related to': c, 
    'The amount of variability explained by the first component is': d,
    'The largest weight of the second component is related to': b,
    'The total amount of variability explained by the first three components': g
}

# %%
# Run this cell to check if your solution matches ours.
t.check_question_five(solution_5_dict)
# Out:
# That's right!  Looks like you know a lot about PCA!

# %% [markdown]
# `6.` How many components need to be kept to explain at least 85% of the variability in the original dataset?  When you think you have the answer, store it in the variable `num_comps`.  Then run the following cell to see if your solution matches ours!

# %%
pca, X_pca = do_pca(6, df)
my_pca_results = pca_results(df, pca)
print("Percentage of variability in the original dataset explained: {:.4f}".format(my_pca_results['Explained Variance'].sum()))
# Out:
# Percentage of variability in the original dataset explained: 0.8682
# C:\Users\ruslan.bergenov\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\ruslan.bergenov\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
for i in range(3,10):
    pca, X_pca = do_pca(i, df)
    my_pca_results = pca_results(df, pca)
    print("Features: {:.0f}".format(i))
    percent_explained = my_pca_results['Explained Variance'].sum()
    print("Percentage of variability in the original dataset explained: {:.4f}".format(percent_explained))
    print()
    if percent_explained >=0.85:
        print("Reached target percentage of variability in the original dataset explained:")
        break
# Out:
# C:\Users\ruslan.bergenov\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\ruslan.bergenov\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# C:\Users\ruslan.bergenov\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\ruslan.bergenov\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# C:\Users\ruslan.bergenov\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\ruslan.bergenov\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# Features: 3
# Percentage of variability in the original dataset explained: 0.7053
#
# Features: 4
# Percentage of variability in the original dataset explained: 0.7684
#
# Features: 5
# Percentage of variability in the original dataset explained: 0.8240
# C:\Users\ruslan.bergenov\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\ruslan.bergenov\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# Features: 6
# Percentage of variability in the original dataset explained: 0.8682
#
# Reached target percentage of variability in the original dataset explained:

# %%
#Code to find number of components providing more than 
# 85% of variance explained

num_comps = 6

# %%
# Now check your answer here to complete this mini project!
display.HTML(t.question_check_six(num_comps))
# Out:
# Nice job!  That's right!  With 6 components, you can explain more than 85% of the variability in the original dataset.
# <img src="https://bit.ly/2cKTiso">
